# %%
import my_packages.Transformers.StringTransformer as ST
import os
os.listdir("./my_packages/Transformers")
dir(ST)
text="here i am"
text_reverse=ST.reverse_string(text)
text_cap=ST.capitalize_string(text)


print(text_reverse+"\n"+text_cap)
# Out:
# am i here
# HERE I AM

# %%
from my_packages.Operations.Math import get_average

lst=[2,3,4,5,6]

get_average(lst)
# Out:
# 4.0
